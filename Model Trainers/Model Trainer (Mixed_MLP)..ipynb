# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
# Load RAVDESS Dataset
paths = []
labels = []
label_map = {'01': 'neutral', '02': 'calm', '03': 'happy', '04': 'sad', '05': 'angry', '06': 'fearful', '07': 'disgust', '08': 'surprised'}
for dirname, _, filenames in os.walk('../RAVDESS_Audio_Speech_Actors_01-24'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('-')[2]
        label = label_map[label]
        labels.append(label.lower())
    if len(paths) == 2800:
        break

print(labels[:3])
print('Dataset is Loaded')
# Out:
# ['neutral', 'neutral', 'neutral']
# Dataset is Loaded

# %%
len(paths), len(labels)
# Out:
# (1440, 1440)

# %%
# Create a dataframe
ravdess = pd.DataFrame()
ravdess['speech'] = paths
ravdess['label'] = labels
ravdess.head()
# Out:
#                                               speech    label
# 0  ../RAVDESS_Audio_Speech_Actors_01-24\Actor_01\...  neutral
# 1  ../RAVDESS_Audio_Speech_Actors_01-24\Actor_01\...  neutral
# 2  ../RAVDESS_Audio_Speech_Actors_01-24\Actor_01\...  neutral
# 3  ../RAVDESS_Audio_Speech_Actors_01-24\Actor_01\...  neutral
# 4  ../RAVDESS_Audio_Speech_Actors_01-24\Actor_01\...     calm

# %%
ravdess['label'].value_counts()
# Out:
# label
# calm         192
# happy        192
# sad          192
# angry        192
# fearful      192
# disgust      192
# surprised    192
# neutral       96
# Name: count, dtype: int64

# %%
# Load TESS Dataset
paths = []
labels = []
for dirname, _, filenames in os.walk('../TESS data'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())

print(labels[:5])
print('Dataset is Loaded')
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
## Create a dataframe
tess = pd.DataFrame()
tess['speech'] = paths
tess['label'] = labels
tess.head()
# Out:
#                                       speech  label
# 0  ../TESS data\OAF_angry\OAF_back_angry.wav  angry
# 1   ../TESS data\OAF_angry\OAF_bar_angry.wav  angry
# 2  ../TESS data\OAF_angry\OAF_base_angry.wav  angry
# 3  ../TESS data\OAF_angry\OAF_bath_angry.wav  angry
# 4  ../TESS data\OAF_angry\OAF_bean_angry.wav  angry

# %%
tess['label'].value_counts()
# Out:
# label
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: count, dtype: int64

# %%
# Mix both datasets
tess['label'] = tess['label'].replace('ps', 'surprised')
tess['label'] = tess['label'].replace('fear', 'fearful')

# delete calm label from ravdess
ravdess = ravdess[ravdess['label'] != 'calm']

# print the number of data of neutral in ravdess
print(ravdess['label'].value_counts())
# Out:
# label
# happy        192
# sad          192
# angry        192
# fearful      192
# disgust      192
# surprised    192
# neutral       96
# Name: count, dtype: int64

# %%
# Combine both datasets
df = pd.concat([ravdess, tess], axis=0, ignore_index=True)
df['label'].value_counts()
# Out:
# label
# happy        592
# sad          592
# angry        592
# fearful      592
# disgust      592
# surprised    592
# neutral      496
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'fearful'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-6.7019543e+02,  6.5063850e+01,  8.8895434e-01,  1.4715979e+01,
#         9.1821651e+00,  6.6057485e-01, -3.8468359e+00, -3.5839462e+00,
#        -1.2959006e+01, -3.3001330e+00,  9.1077960e-01, -3.5970356e+00,
#         2.3762746e+00, -4.3889413e+00,  5.4508030e-01,  8.9185178e-01,
#        -4.8025899e+00, -2.1054137e+00, -1.6059692e+00, -1.0523903e+00,
#        -7.0672808e+00, -6.2306100e-01, -2.7280297e+00, -5.3073611e+00,
#        -1.9691168e+00, -9.4615275e-01, -5.7211108e+00,  3.3299121e-01,
#        -2.5438452e+00,  1.8220846e-01, -2.3510973e+00, -2.5047269e+00,
#        -3.1515071e+00, -2.1908989e+00, -3.8017597e+00, -1.8130877e+00,
#        -1.2612224e+00, -2.1449544e+00, -4.1521730e+00, -1.7796154e+00],
#       dtype=float32)

# %%
print(df.shape)
# Out:
# (4048, 2)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (4048, 40)

# %%
## input split
X.shape
# Out:
# (4048, 40)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (4048, 7)

# %%
enc.categories_
# Out:
# [array(['angry', 'disgust', 'fearful', 'happy', 'neutral', 'sad',
#         'surprised'], dtype=object)]

# %%
# LSTM Model
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, Flatten

model = Sequential([
    Dense(64, input_shape=(40,), activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         2,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,935 (19.28 KB)
#  Trainable params: 4,935 (19.28 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

history = model.fit(X_train, y_train, epochs=300, batch_size=64, validation_data=(X_test, y_test), callbacks=[early_stopping])
# history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1403 - loss: 44.2657 - val_accuracy: 0.2210 - val_loss: 3.7294
# Epoch 2/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1849 - loss: 10.3152 - val_accuracy: 0.1654 - val_loss: 1.9421
# Epoch 3/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1891 - loss: 3.2031 - val_accuracy: 0.1519 - val_loss: 1.9472
# Epoch 4/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1661 - loss: 2.3678 - val_accuracy: 0.1519 - val_loss: 1.9470
# Epoch 5/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1728 - loss: 2.1586 - val_accuracy: 0.1531 - val_loss: 1.9463
# Epoch 6/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1828 - loss: 2.0366 - val_accuracy: 0.1519 - val_loss: 1.9460
# Epoch 7/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1569 - loss: 2.0761 - val_accuracy: 0.1580 - val_loss: 1.9430
# Epoch 8/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1586 - loss: 1.9888 - val_accuracy: 0.1679 - val_loss: 1.9346
# Epoch 9/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1715 - loss: 1.9960 - val_accuracy: 0.1914 - val_loss: 1.9100
# Epoch 10/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1776 - loss: 1.9711 - val_accuracy: 0.1914 - val_loss: 1.9092
# Epoch 11/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1850 - loss: 1.9651 - val_accuracy: 0.1963 - val_loss: 1.8933
# Epoch 12/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1935 - loss: 1.8972 - val_accuracy: 0.1988 - val_loss: 1.8664
# Epoch 13/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2018 - loss: 1.9076 - val_accuracy: 0.1988 - val_loss: 1.8595
# Epoch 14/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2047 - loss: 1.8882 - val_accuracy: 0.2173 - val_loss: 1.8118
# Epoch 15/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2144 - loss: 1.8756 - val_accuracy: 0.2148 - val_loss: 1.8074
# Epoch 16/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2167 - loss: 1.8446 - val_accuracy: 0.2136 - val_loss: 1.8063
# Epoch 17/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2186 - loss: 1.8424 - val_accuracy: 0.2173 - val_loss: 1.7818
# Epoch 18/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2144 - loss: 1.8139 - val_accuracy: 0.2185 - val_loss: 1.7879
# Epoch 19/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2203 - loss: 1.8236 - val_accuracy: 0.2198 - val_loss: 1.7764
# Epoch 20/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2238 - loss: 1.7986 - val_accuracy: 0.2210 - val_loss: 1.7638
# Epoch 21/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2337 - loss: 1.8063 - val_accuracy: 0.2198 - val_loss: 1.7741
# Epoch 22/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2204 - loss: 1.7999 - val_accuracy: 0.2247 - val_loss: 1.7584
# Epoch 23/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2208 - loss: 1.7828 - val_accuracy: 0.2247 - val_loss: 1.7528
# Epoch 24/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2276 - loss: 1.7798 - val_accuracy: 0.2235 - val_loss: 1.7583
# Epoch 25/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2313 - loss: 1.7956 - val_accuracy: 0.2247 - val_loss: 1.7478
# Epoch 26/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2212 - loss: 1.7729 - val_accuracy: 0.2321 - val_loss: 1.7339
# Epoch 27/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2255 - loss: 1.7822 - val_accuracy: 0.2259 - val_loss: 1.7392
# Epoch 28/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2307 - loss: 1.7649 - val_accuracy: 0.2272 - val_loss: 1.7354
# Epoch 29/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2148 - loss: 1.7791 - val_accuracy: 0.2333 - val_loss: 1.7251
# Epoch 30/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2295 - loss: 1.7663 - val_accuracy: 0.2284 - val_loss: 1.7340
# Epoch 31/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2214 - loss: 1.7903 - val_accuracy: 0.2346 - val_loss: 1.7233
# Epoch 32/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2402 - loss: 1.7540 - val_accuracy: 0.2296 - val_loss: 1.7273
# Epoch 33/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2192 - loss: 1.7864 - val_accuracy: 0.2358 - val_loss: 1.7192
# Epoch 34/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2339 - loss: 1.7498 - val_accuracy: 0.2321 - val_loss: 1.7217
# Epoch 35/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2330 - loss: 1.7613 - val_accuracy: 0.2309 - val_loss: 1.7226
# Epoch 36/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2635 - loss: 1.7300 - val_accuracy: 0.2654 - val_loss: 1.6784
# Epoch 37/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2783 - loss: 1.7038 - val_accuracy: 0.3704 - val_loss: 1.5913
# Epoch 38/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3418 - loss: 1.6310 - val_accuracy: 0.3716 - val_loss: 1.5274
# Epoch 39/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3445 - loss: 1.6219 - val_accuracy: 0.4420 - val_loss: 1.5181
# Epoch 40/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3471 - loss: 1.5785 - val_accuracy: 0.4444 - val_loss: 1.4639
# Epoch 41/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3690 - loss: 1.5524 - val_accuracy: 0.4481 - val_loss: 1.4535
# Epoch 42/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3685 - loss: 1.5311 - val_accuracy: 0.4556 - val_loss: 1.4460
# Epoch 43/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3699 - loss: 1.5581 - val_accuracy: 0.4444 - val_loss: 1.4092
# Epoch 44/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4029 - loss: 1.4892 - val_accuracy: 0.4556 - val_loss: 1.4118
# Epoch 45/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3878 - loss: 1.4696 - val_accuracy: 0.4605 - val_loss: 1.3981
# Epoch 46/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3925 - loss: 1.4824 - val_accuracy: 0.4568 - val_loss: 1.3661
# Epoch 47/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4131 - loss: 1.4448 - val_accuracy: 0.4543 - val_loss: 1.3555
# Epoch 48/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3771 - loss: 1.5046 - val_accuracy: 0.4667 - val_loss: 1.3582
# Epoch 49/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4013 - loss: 1.4638 - val_accuracy: 0.4691 - val_loss: 1.3469
# Epoch 50/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4011 - loss: 1.4449 - val_accuracy: 0.4975 - val_loss: 1.3162
# Epoch 51/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4385 - loss: 1.3732 - val_accuracy: 0.5481 - val_loss: 1.2586
# Epoch 52/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4928 - loss: 1.3181 - val_accuracy: 0.5383 - val_loss: 1.2113
# Epoch 53/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.
300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7830 - loss: 0.5570 - val_accuracy: 0.7914 - val_loss: 0.5423
# Epoch 152/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7737 - loss: 0.5722 - val_accuracy: 0.7889 - val_loss: 0.5372
# Epoch 153/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7850 - loss: 0.5439 - val_accuracy: 0.7926 - val_loss: 0.5397
# Epoch 154/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7773 - loss: 0.5603 - val_accuracy: 0.7901 - val_loss: 0.5411
# Epoch 155/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7805 - loss: 0.5541 - val_accuracy: 0.7889 - val_loss: 0.5355
# Epoch 156/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7911 - loss: 0.5431 - val_accuracy: 0.7963 - val_loss: 0.5358
# Epoch 157/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7929 - loss: 0.5324 - val_accuracy: 0.8037 - val_loss: 0.5393
# Epoch 158/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7842 - loss: 0.5756 - val_accuracy: 0.7988 - val_loss: 0.5384
# Epoch 159/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7856 - loss: 0.5735 - val_accuracy: 0.8037 - val_loss: 0.5353
# Epoch 160/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7899 - loss: 0.5369 - val_accuracy: 0.7963 - val_loss: 0.5342
# Epoch 161/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7802 - loss: 0.5600 - val_accuracy: 0.7901 - val_loss: 0.5303
# Epoch 162/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7734 - loss: 0.5617 - val_accuracy: 0.7926 - val_loss: 0.5365
# Epoch 163/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7907 - loss: 0.5366 - val_accuracy: 0.7975 - val_loss: 0.5308
# Epoch 164/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7859 - loss: 0.5528 - val_accuracy: 0.7963 - val_loss: 0.5336
# Epoch 165/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7812 - loss: 0.5483 - val_accuracy: 0.7988 - val_loss: 0.5322
# Epoch 166/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7904 - loss: 0.5442 - val_accuracy: 0.7951 - val_loss: 0.5374
# Epoch 167/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7938 - loss: 0.5419 - val_accuracy: 0.7926 - val_loss: 0.5292
# Epoch 168/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8029 - loss: 0.5209 - val_accuracy: 0.7963 - val_loss: 0.5301
# Epoch 169/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7961 - loss: 0.5285 - val_accuracy: 0.7975 - val_loss: 0.5386
# Epoch 170/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7851 - loss: 0.5595 - val_accuracy: 0.7926 - val_loss: 0.5342
# Epoch 171/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8056 - loss: 0.5165 - val_accuracy: 0.7901 - val_loss: 0.5375
# Epoch 172/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7997 - loss: 0.5258 - val_accuracy: 0.7852 - val_loss: 0.5437
# Epoch 173/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7861 - loss: 0.5233 - val_accuracy: 0.7901 - val_loss: 0.5296
# Epoch 174/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7827 - loss: 0.5688 - val_accuracy: 0.7852 - val_loss: 0.5319
# Epoch 175/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7927 - loss: 0.5407 - val_accuracy: 0.8062 - val_loss: 0.5255
# Epoch 176/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7874 - loss: 0.5386 - val_accuracy: 0.8037 - val_loss: 0.5232
# Epoch 177/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8002 - loss: 0.5344 - val_accuracy: 0.8025 - val_loss: 0.5229
# Epoch 178/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8140 - loss: 0.5092 - val_accuracy: 0.8025 - val_loss: 0.5211
# Epoch 179/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7884 - loss: 0.5332 - val_accuracy: 0.7975 - val_loss: 0.5224
# Epoch 180/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7866 - loss: 0.5361 - val_accuracy: 0.7975 - val_loss: 0.5311
# Epoch 181/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7956 - loss: 0.5282 - val_accuracy: 0.8025 - val_loss: 0.5244
# Epoch 182/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8008 - loss: 0.5310 - val_accuracy: 0.7975 - val_loss: 0.5282
# Epoch 183/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7996 - loss: 0.5153 - val_accuracy: 0.7889 - val_loss: 0.5316
# Epoch 184/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8071 - loss: 0.5042 - val_accuracy: 0.8000 - val_loss: 0.5195
# Epoch 185/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8007 - loss: 0.5163 - val_accuracy: 0.7951 - val_loss: 0.5229
# Epoch 186/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7762 - loss: 0.5708 - val_accuracy: 0.8111 - val_loss: 0.5172
# Epoch 187/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8000 - loss: 0.4976 - val_accuracy: 0.7963 - val_loss: 0.5340
# Epoch 188/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8011 - loss: 0.5110 - val_accuracy: 0.7963 - val_loss: 0.5109
# Epoch 189/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8004 - loss: 0.5038 - val_accuracy: 0.8099 - val_loss: 0.5162
# Epoch 190/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7918 - loss: 0.5284 - val_accuracy: 0.7975 - val_loss: 0.5184
# Epoch 191/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7932 - loss: 0.5332 - val_accuracy: 0.8062 - val_loss: 0.5102
# Epoch 192/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8106 - loss: 0.5057 - val_accuracy: 0.8000 - val_loss: 0.5170
# Epoch 193/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7960 - loss: 0.5191 - val_accuracy: 0.8099 - val_loss: 0.5174
# Epoch 194/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8039 - loss: 0.5060 - val_accuracy: 0.7926 - val_loss: 0.5239
# Epoch 195/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7994 - loss: 0.5182 - val_accuracy: 0.8000 - val_loss: 0.5151
# Epoch 196/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7980 - loss: 0.5305 - val_accuracy: 0.8037 - val_loss: 0.5064
# Epoch 197/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7874 - loss: 0.5175 - val_accuracy: 0.8062 - val_loss: 0.5134
# Epoch 198/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8067 - loss: 0.5154 - val_accuracy: 0.8000 - val_loss: 0.5144
# Epoch 199/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7922 - loss: 0.5177 - val_accuracy: 0.8037 - val_loss: 0.5141
# Epoch 200/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8047 - loss: 0.5057 - val_accuracy: 0.8012 - val_loss: 0.5115
# Epoch 201/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8104 - loss: 0.5065 - val_accuracy: 0.7975 - val_loss: 0.5153
# Epoch 202/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8009 - loss: 0.5007 - val_accuracy: 0.8025 - val_loss: 0.5157
# Epoch 203/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8022 - loss: 0.4983 - val_accuracy: 0.8062 - val_loss: 0.5144
# Epoch 204/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7965 - loss: 0.5112 - val_accuracy: 0.7963 - val_loss: 0.5115
# Epoch 205/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8069 - loss: 0.4943 - val_accuracy: 0.8062 - val_loss: 0.5167
# Epoch 206/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7979 - loss: 0.5247 - val_accuracy: 0.8000 - val_loss: 0.5154

# %%
epochs = list(range(len(history.history['accuracy'])))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)

accuracy_score(y_true, y_pred), cm
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step
# (0.8,
#  array([[107,  10,   0,   3,   0,   0,   3],
#         [  3,  98,   0,   1,   0,   9,   6],
#         [  5,   6,  71,  18,   1,  12,   2],
#         [  1,  11,   0,  91,   0,   1,  10],
#         [  0,   6,   0,   0,  69,   3,   2],
#         [  0,  17,   1,   7,   0, 103,   3],
#         [  2,  14,   0,   2,   0,   3, 109]], dtype=int64))

# %%
# print colorful confusion matrix
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='coolwarm', xticklabels=enc.categories_[0], yticklabels=enc.categories_[0])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt

lb = LabelBinarizer()
y_test = lb.fit_transform(y_test)
y_pred = model.predict(X_test)
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

for i in range(7):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic for '+enc.categories_[0][i])
    plt.legend(loc="lower right")
    plt.show()
# Out:
#  1/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step

# %%
#save model
model.save('..\Models\emotion_detection_mixed_MLP.keras')
