# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
# Load RAVDESS Dataset
paths = []
labels = []
label_map = {'01': 'neutral', '02': 'calm', '03': 'happy', '04': 'sad', '05': 'angry', '06': 'fearful', '07': 'disgust', '08': 'surprised'}
for dirname, _, filenames in os.walk('../RAVDESS_Audio_Speech_Actors_01-24'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('-')[2]
        label = label_map[label]
        labels.append(label.lower())
    if len(paths) == 2800:
        break

print(labels[:3])
print('Dataset is Loaded')
# Out:
# ['neutral', 'neutral', 'neutral']
# Dataset is Loaded

# %%
len(paths), len(labels)
# Out:
# (1440, 1440)

# %%
# Create a dataframe
ravdess = pd.DataFrame()
ravdess['speech'] = paths
ravdess['label'] = labels
ravdess.head()
# Out:
#                                               speech    label
# 0  ../RAVDESS_Audio_Speech_Actors_01-24\Actor_01\...  neutral
# 1  ../RAVDESS_Audio_Speech_Actors_01-24\Actor_01\...  neutral
# 2  ../RAVDESS_Audio_Speech_Actors_01-24\Actor_01\...  neutral
# 3  ../RAVDESS_Audio_Speech_Actors_01-24\Actor_01\...  neutral
# 4  ../RAVDESS_Audio_Speech_Actors_01-24\Actor_01\...     calm

# %%
ravdess['label'].value_counts()
# Out:
# label
# calm         192
# happy        192
# sad          192
# angry        192
# fearful      192
# disgust      192
# surprised    192
# neutral       96
# Name: count, dtype: int64

# %%
# Load TESS Dataset
paths = []
labels = []
for dirname, _, filenames in os.walk('../TESS data'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())

print(labels[:5])
print('Dataset is Loaded')
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
## Create a dataframe
tess = pd.DataFrame()
tess['speech'] = paths
tess['label'] = labels
tess.head()
# Out:
#                                       speech  label
# 0  ../TESS data\OAF_angry\OAF_back_angry.wav  angry
# 1   ../TESS data\OAF_angry\OAF_bar_angry.wav  angry
# 2  ../TESS data\OAF_angry\OAF_base_angry.wav  angry
# 3  ../TESS data\OAF_angry\OAF_bath_angry.wav  angry
# 4  ../TESS data\OAF_angry\OAF_bean_angry.wav  angry

# %%
tess['label'].value_counts()
# Out:
# label
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: count, dtype: int64

# %%
# Mix both datasets
tess['label'] = tess['label'].replace('ps', 'surprised')
tess['label'] = tess['label'].replace('fear', 'fearful')

# delete calm label from ravdess
ravdess = ravdess[ravdess['label'] != 'calm']

# print the number of data of neutral in ravdess
print(ravdess['label'].value_counts())
# Out:
# label
# happy        192
# sad          192
# angry        192
# fearful      192
# disgust      192
# surprised    192
# neutral       96
# Name: count, dtype: int64

# %%
# Combine both datasets
df = pd.concat([ravdess, tess], axis=0, ignore_index=True)
df['label'].value_counts()
# Out:
# label
# happy        592
# sad          592
# angry        592
# fearful      592
# disgust      592
# surprised    592
# neutral      496
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'fearful'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-6.7019543e+02,  6.5063850e+01,  8.8895434e-01,  1.4715979e+01,
#         9.1821651e+00,  6.6057485e-01, -3.8468359e+00, -3.5839462e+00,
#        -1.2959006e+01, -3.3001330e+00,  9.1077960e-01, -3.5970356e+00,
#         2.3762746e+00, -4.3889413e+00,  5.4508030e-01,  8.9185178e-01,
#        -4.8025899e+00, -2.1054137e+00, -1.6059692e+00, -1.0523903e+00,
#        -7.0672808e+00, -6.2306100e-01, -2.7280297e+00, -5.3073611e+00,
#        -1.9691168e+00, -9.4615275e-01, -5.7211108e+00,  3.3299121e-01,
#        -2.5438452e+00,  1.8220846e-01, -2.3510973e+00, -2.5047269e+00,
#        -3.1515071e+00, -2.1908989e+00, -3.8017597e+00, -1.8130877e+00,
#        -1.2612224e+00, -2.1449544e+00, -4.1521730e+00, -1.7796154e+00],
#       dtype=float32)

# %%
print(df.shape)
# Out:
# (4048, 2)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (4048, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (4048, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (4048, 7)

# %%
enc.categories_
# Out:
# [array(['angry', 'disgust', 'fearful', 'happy', 'neutral', 'sad',
#         'surprised'], dtype=object)]

# %%
# LSTM Model
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Conv1D, MaxPooling1D, Flatten

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Flatten(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 256)            │       264,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 305,799 (1.17 MB)
#  Trainable params: 305,799 (1.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test), callbacks=[early_stopping])
# history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.3441 - loss: 1.6149 - val_accuracy: 0.6235 - val_loss: 1.0183
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.6354 - loss: 0.9940 - val_accuracy: 0.6938 - val_loss: 0.8256
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.6949 - loss: 0.8448 - val_accuracy: 0.7111 - val_loss: 0.7480
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.7080 - loss: 0.7978 - val_accuracy: 0.7086 - val_loss: 0.7840
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.7281 - loss: 0.7476 - val_accuracy: 0.7148 - val_loss: 0.7510
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.7288 - loss: 0.7598 - val_accuracy: 0.7395 - val_loss: 0.6699
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.7452 - loss: 0.6950 - val_accuracy: 0.7531 - val_loss: 0.6465
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.7595 - loss: 0.6574 - val_accuracy: 0.7407 - val_loss: 0.6664
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.7644 - loss: 0.6419 - val_accuracy: 0.7432 - val_loss: 0.6378
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.7781 - loss: 0.5969 - val_accuracy: 0.7358 - val_loss: 0.7030
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.7567 - loss: 0.6741 - val_accuracy: 0.7370 - val_loss: 0.6777
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.7601 - loss: 0.6483 - val_accuracy: 0.7605 - val_loss: 0.6160
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.7652 - loss: 0.6232 - val_accuracy: 0.7568 - val_loss: 0.6482
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.7766 - loss: 0.5767 - val_accuracy: 0.7654 - val_loss: 0.5929
# Epoch 15/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7617 - loss: 0.6003 - val_accuracy: 0.7741 - val_loss: 0.5899
# Epoch 16/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.7829 - loss: 0.5778 - val_accuracy: 0.7765 - val_loss: 0.5929
# Epoch 17/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.7876 - loss: 0.5634 - val_accuracy: 0.7568 - val_loss: 0.6171
# Epoch 18/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.7991 - loss: 0.5592 - val_accuracy: 0.7630 - val_loss: 0.6050
# Epoch 19/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.7960 - loss: 0.5454 - val_accuracy: 0.7667 - val_loss: 0.6032
# Epoch 20/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.8021 - loss: 0.5245 - val_accuracy: 0.7630 - val_loss: 0.6030
# Epoch 21/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.7943 - loss: 0.5328 - val_accuracy: 0.7630 - val_loss: 0.5964
# Epoch 22/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.7967 - loss: 0.5218 - val_accuracy: 0.7914 - val_loss: 0.5741
# Epoch 23/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.7972 - loss: 0.5316 - val_accuracy: 0.7864 - val_loss: 0.5739
# Epoch 24/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.8082 - loss: 0.4885 - val_accuracy: 0.7790 - val_loss: 0.5805
# Epoch 25/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.8170 - loss: 0.4831 - val_accuracy: 0.7864 - val_loss: 0.5854
# Epoch 26/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.7984 - loss: 0.4968 - val_accuracy: 0.7926 - val_loss: 0.5747
# Epoch 27/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8164 - loss: 0.4776 - val_accuracy: 0.7963 - val_loss: 0.5476
# Epoch 28/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8198 - loss: 0.4550 - val_accuracy: 0.7679 - val_loss: 0.6156
# Epoch 29/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.8194 - loss: 0.4627 - val_accuracy: 0.7765 - val_loss: 0.6036
# Epoch 30/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8377 - loss: 0.4365 - val_accuracy: 0.7938 - val_loss: 0.5800
# Epoch 31/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.8221 - loss: 0.4480 - val_accuracy: 0.7802 - val_loss: 0.5721
# Epoch 32/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.8374 - loss: 0.4237 - val_accuracy: 0.8037 - val_loss: 0.5566
# Epoch 33/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.8176 - loss: 0.4811 - val_accuracy: 0.7864 - val_loss: 0.6173
# Epoch 34/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.8309 - loss: 0.4355 - val_accuracy: 0.8012 - val_loss: 0.5517
# Epoch 35/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.8321 - loss: 0.4198 - val_accuracy: 0.7889 - val_loss: 0.5893
# Epoch 36/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.8311 - loss: 0.4487 - val_accuracy: 0.8160 - val_loss: 0.5537
# Epoch 37/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.8321 - loss: 0.4285 - val_accuracy: 0.8062 - val_loss: 0.6045

# %%
epochs = list(range(len(history.history['accuracy'])))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)

accuracy_score(y_true, y_pred), cm
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# (0.8061728395061728,
#  array([[108,   3,   1,   5,   1,   4,   1],
#         [  0,  99,   2,   6,   0,   7,   3],
#         [ 13,   8,  76,   7,   1,   7,   3],
#         [ 11,   5,   4,  89,   1,   2,   2],
#         [  0,   2,   1,   2,  72,   2,   1],
#         [  4,   8,   7,   2,   4, 104,   2],
#         [  6,   8,   3,   4,   1,   3, 105]], dtype=int64))

# %%
# Out:
# array(['angry', 'disgust', 'fearful', 'happy', 'neutral', 'sad',
#        'surprised'], dtype=object)

# %%
# print colorful confusion matrix
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='coolwarm', xticklabels=enc.categories_[0], yticklabels=enc.categories_[0])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# #save model
# model.save('..\Models\emotion_detection_mixed_LSTM_1.keras')

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt

lb = LabelBinarizer()
y_test = lb.fit_transform(y_test)
y_pred = model.predict(X_test)
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

for i in range(7):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic for '+enc.categories_[0][i])
    plt.legend(loc="lower right")
    plt.show()
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
