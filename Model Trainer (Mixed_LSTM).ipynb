# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
# Load RAVDESS Dataset
paths = []
labels = []
label_map = {'01': 'neutral', '02': 'calm', '03': 'happy', '04': 'sad', '05': 'angry', '06': 'fearful', '07': 'disgust', '08': 'surprised'}
for dirname, _, filenames in os.walk('RAVDESS_Audio_Speech_Actors_01-24'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('-')[2]
        label = label_map[label]
        labels.append(label.lower())
    if len(paths) == 2800:
        break

print(labels[:3])
print('Dataset is Loaded')
# Out:
# ['neutral', 'neutral', 'neutral']
# Dataset is Loaded

# %%
len(paths), len(labels)
# Out:
# (1440, 1440)

# %%
# Create a dataframe
ravdess = pd.DataFrame()
ravdess['speech'] = paths
ravdess['label'] = labels
ravdess.head()
# Out:
#                                               speech    label
# 0  RAVDESS_Audio_Speech_Actors_01-24\Actor_01\03-...  neutral
# 1  RAVDESS_Audio_Speech_Actors_01-24\Actor_01\03-...  neutral
# 2  RAVDESS_Audio_Speech_Actors_01-24\Actor_01\03-...  neutral
# 3  RAVDESS_Audio_Speech_Actors_01-24\Actor_01\03-...  neutral
# 4  RAVDESS_Audio_Speech_Actors_01-24\Actor_01\03-...     calm

# %%
ravdess['label'].value_counts()
# Out:
# label
# calm         192
# happy        192
# sad          192
# angry        192
# fearful      192
# disgust      192
# surprised    192
# neutral       96
# Name: count, dtype: int64

# %%
# Load TESS Dataset
paths = []
labels = []
for dirname, _, filenames in os.walk('TESS data'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())

print(labels[:5])
print('Dataset is Loaded')
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
## Create a dataframe
tess = pd.DataFrame()
tess['speech'] = paths
tess['label'] = labels
tess.head()
# Out:
#                                    speech  label
# 0  TESS data\OAF_angry\OAF_back_angry.wav  angry
# 1   TESS data\OAF_angry\OAF_bar_angry.wav  angry
# 2  TESS data\OAF_angry\OAF_base_angry.wav  angry
# 3  TESS data\OAF_angry\OAF_bath_angry.wav  angry
# 4  TESS data\OAF_angry\OAF_bean_angry.wav  angry

# %%
tess['label'].value_counts()
# Out:
# label
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: count, dtype: int64

# %%
# Mix both datasets
tess['label'] = tess['label'].replace('ps', 'surprised')
tess['label'] = tess['label'].replace('fear', 'fearful')

# delete calm label from ravdess
ravdess = ravdess[ravdess['label'] != 'calm']

# print the number of data of neutral in ravdess
print(ravdess['label'].value_counts())
# Out:
# label
# happy        192
# sad          192
# angry        192
# fearful      192
# disgust      192
# surprised    192
# neutral       96
# Name: count, dtype: int64

# %%
# Combine both datasets
df = pd.concat([ravdess, tess], axis=0, ignore_index=True)
df['label'].value_counts()
# Out:
# label
# happy        592
# sad          592
# angry        592
# fearful      592
# disgust      592
# surprised    592
# neutral      496
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'fearful'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-6.7019543e+02,  6.5063850e+01,  8.8895434e-01,  1.4715979e+01,
#         9.1821651e+00,  6.6057485e-01, -3.8468359e+00, -3.5839462e+00,
#        -1.2959006e+01, -3.3001330e+00,  9.1077960e-01, -3.5970356e+00,
#         2.3762746e+00, -4.3889413e+00,  5.4508030e-01,  8.9185178e-01,
#        -4.8025899e+00, -2.1054137e+00, -1.6059692e+00, -1.0523903e+00,
#        -7.0672808e+00, -6.2306100e-01, -2.7280297e+00, -5.3073611e+00,
#        -1.9691168e+00, -9.4615275e-01, -5.7211108e+00,  3.3299121e-01,
#        -2.5438452e+00,  1.8220846e-01, -2.3510973e+00, -2.5047269e+00,
#        -3.1515071e+00, -2.1908989e+00, -3.8017597e+00, -1.8130877e+00,
#        -1.2612224e+00, -2.1449544e+00, -4.1521730e+00, -1.7796154e+00],
#       dtype=float32)

# %%
print(df.shape)
# Out:
# (4048, 2)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (4048, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (4048, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (4048, 7)

# %%
enc.categories_
# Out:
# [array(['angry', 'disgust', 'fearful', 'happy', 'neutral', 'sad',
#         'surprised'], dtype=object)]

# %%
# LSTM Model
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Conv1D, MaxPooling1D, Flatten

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Flatten(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\19746\anaconda3\envs\CS539\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\19746\anaconda3\envs\CS539\Lib\site-packages\keras\src\layers\rnn\lstm.py:148: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\19746\anaconda3\envs\CS539\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               264192
#
#  flatten (Flatten)           (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 305799 (1.17 MB)
# Trainable params: 305799 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# history = model.fit(X, y, epochs=50, batch_size=64, validation_split=0.2, callbacks=[early_stopping])
history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\19746\anaconda3\envs\CS539\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\19746\anaconda3\envs\CS539\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 51/51 [==============================] - 6s 71ms/step - loss: 1.4049 - accuracy: 0.4370 - val_loss: 1.0562 - val_accuracy: 0.6247
# Epoch 2/50
# 51/51 [==============================] - 3s 64ms/step - loss: 0.9819 - accuracy: 0.6455 - val_loss: 0.8477 - val_accuracy: 0.6753
# Epoch 3/50
# 51/51 [==============================] - 3s 66ms/step - loss: 0.8709 - accuracy: 0.6936 - val_loss: 0.7547 - val_accuracy: 0.7210
# Epoch 4/50
# 51/51 [==============================] - 3s 58ms/step - loss: 0.7739 - accuracy: 0.7248 - val_loss: 0.7428 - val_accuracy: 0.7309
# Epoch 5/50
# 51/51 [==============================] - 3s 61ms/step - loss: 0.7838 - accuracy: 0.7276 - val_loss: 0.7239 - val_accuracy: 0.7358
# Epoch 6/50
# 51/51 [==============================] - 3s 58ms/step - loss: 0.7349 - accuracy: 0.7322 - val_loss: 0.6710 - val_accuracy: 0.7481
# Epoch 7/50
# 51/51 [==============================] - 3s 60ms/step - loss: 0.7159 - accuracy: 0.7452 - val_loss: 0.7520 - val_accuracy: 0.7185
# Epoch 8/50
# 51/51 [==============================] - 3s 66ms/step - loss: 0.6856 - accuracy: 0.7455 - val_loss: 0.7820 - val_accuracy: 0.7222
# Epoch 9/50
# 51/51 [==============================] - 3s 66ms/step - loss: 0.6849 - accuracy: 0.7545 - val_loss: 0.6592 - val_accuracy: 0.7457
# Epoch 10/50
# 51/51 [==============================] - 3s 59ms/step - loss: 0.6310 - accuracy: 0.7641 - val_loss: 0.6105 - val_accuracy: 0.7654
# Epoch 11/50
# 51/51 [==============================] - 3s 58ms/step - loss: 0.6336 - accuracy: 0.7542 - val_loss: 0.6106 - val_accuracy: 0.7691
# Epoch 12/50
# 51/51 [==============================] - 3s 59ms/step - loss: 0.5962 - accuracy: 0.7770 - val_loss: 0.6206 - val_accuracy: 0.7630
# Epoch 13/50
# 51/51 [==============================] - 3s 59ms/step - loss: 0.5901 - accuracy: 0.7746 - val_loss: 0.6027 - val_accuracy: 0.7790
# Epoch 14/50
# 51/51 [==============================] - 3s 58ms/step - loss: 0.5678 - accuracy: 0.7863 - val_loss: 0.6035 - val_accuracy: 0.7716
# Epoch 15/50
# 51/51 [==============================] - 3s 56ms/step - loss: 0.5533 - accuracy: 0.7881 - val_loss: 0.5731 - val_accuracy: 0.7938
# Epoch 16/50
# 51/51 [==============================] - 3s 56ms/step - loss: 0.5635 - accuracy: 0.7854 - val_loss: 0.5580 - val_accuracy: 0.8012
# Epoch 17/50
# 51/51 [==============================] - 3s 57ms/step - loss: 0.5746 - accuracy: 0.7801 - val_loss: 0.5655 - val_accuracy: 0.7988
# Epoch 18/50
# 51/51 [==============================] - 3s 57ms/step - loss: 0.5229 - accuracy: 0.7968 - val_loss: 0.5713 - val_accuracy: 0.7877
# Epoch 19/50
# 51/51 [==============================] - 3s 55ms/step - loss: 0.5261 - accuracy: 0.7918 - val_loss: 0.5468 - val_accuracy: 0.8000
# Epoch 20/50
# 51/51 [==============================] - 3s 58ms/step - loss: 0.5271 - accuracy: 0.7993 - val_loss: 0.5828 - val_accuracy: 0.7827
# Epoch 21/50
# 51/51 [==============================] - 3s 54ms/step - loss: 0.5176 - accuracy: 0.8116 - val_loss: 0.5550 - val_accuracy: 0.7914
# Epoch 22/50
# 51/51 [==============================] - 3s 54ms/step - loss: 0.5013 - accuracy: 0.8116 - val_loss: 0.5847 - val_accuracy: 0.7864
# Epoch 23/50
# 51/51 [==============================] - 3s 54ms/step - loss: 0.4952 - accuracy: 0.8132 - val_loss: 0.5614 - val_accuracy: 0.7901
# Epoch 24/50
# 51/51 [==============================] - 3s 54ms/step - loss: 0.4820 - accuracy: 0.8206 - val_loss: 0.5549 - val_accuracy: 0.7914
# Epoch 25/50
# 51/51 [==============================] - 3s 56ms/step - loss: 0.4928 - accuracy: 0.8128 - val_loss: 0.6093 - val_accuracy: 0.7802
# Epoch 26/50
# 51/51 [==============================] - 3s 55ms/step - loss: 0.4917 - accuracy: 0.8172 - val_loss: 0.5317 - val_accuracy: 0.8099
# Epoch 27/50
# 51/51 [==============================] - 3s 54ms/step - loss: 0.4787 - accuracy: 0.8156 - val_loss: 0.5833 - val_accuracy: 0.7815
# Epoch 28/50
# 51/51 [==============================] - 3s 53ms/step - loss: 0.4745 - accuracy: 0.8138 - val_loss: 0.5632 - val_accuracy: 0.7988
# Epoch 29/50
# 51/51 [==============================] - 3s 54ms/step - loss: 0.4474 - accuracy: 0.8271 - val_loss: 0.5848 - val_accuracy: 0.7852
# Epoch 30/50
# 51/51 [==============================] - 3s 57ms/step - loss: 0.4269 - accuracy: 0.8406 - val_loss: 0.6039 - val_accuracy: 0.7852
# Epoch 31/50
# 51/51 [==============================] - 3s 54ms/step - loss: 0.4787 - accuracy: 0.8246 - val_loss: 0.5287 - val_accuracy: 0.8123
# Epoch 32/50
# 51/51 [==============================] - 3s 52ms/step - loss: 0.4168 - accuracy: 0.8400 - val_loss: 0.5884 - val_accuracy: 0.7901
# Epoch 33/50
# 51/51 [==============================] - 3s 53ms/step - loss: 0.4493 - accuracy: 0.8329 - val_loss: 0.5649 - val_accuracy: 0.7827
# Epoch 34/50
# 51/51 [==============================] - 3s 52ms/step - loss: 0.4199 - accuracy: 0.8397 - val_loss: 0.5731 - val_accuracy: 0.7864
# Epoch 35/50
# 51/51 [==============================] - 3s 51ms/step - loss: 0.4001 - accuracy: 0.8484 - val_loss: 0.5505 - val_accuracy: 0.8012
# Epoch 36/50
# 51/51 [==============================] - 3s 51ms/step - loss: 0.4093 - accuracy: 0.8403 - val_loss: 0.6128 - val_accuracy: 0.7827
# Epoch 37/50
# 51/51 [==============================] - 3s 52ms/step - loss: 0.4096 - accuracy: 0.8462 - val_loss: 0.5523 - val_accuracy: 0.7951
# Epoch 38/50
# 51/51 [==============================] - 3s 51ms/step - loss: 0.3796 - accuracy: 0.8533 - val_loss: 0.5524 - val_accuracy: 0.8049
# Epoch 39/50
# 51/51 [==============================] - 3s 52ms/step - loss: 0.3593 - accuracy: 0.8623 - val_loss: 0.5457 - val_accuracy: 0.8049
# Epoch 40/50
# 51/51 [==============================] - 3s 51ms/step - loss: 0.3698 - accuracy: 0.8521 - val_loss: 0.5435 - val_accuracy: 0.8049
# Epoch 41/50
# 51/51 [==============================] - 3s 53ms/step - loss: 0.3778 - accuracy: 0.8570 - val_loss: 0.5726 - val_accuracy: 0.7951
# Epoch 42/50
# 51/51 [==============================] - 3s 52ms/step - loss: 0.3834 - accuracy: 0.8567 - val_loss: 0.5608 - val_accuracy: 0.8074
# Epoch 43/50
# 51/51 [==============================] - 3s 53ms/step - loss: 0.3587 - accuracy: 0.8650 - val_loss: 0.5852 - val_accuracy: 0.8185
# Epoch 44/50
# 51/51 [==============================] - 3s 51ms/step - loss: 0.3282 - accuracy: 0.8740 - val_loss: 0.5852 - val_accuracy: 0.8074
# Epoch 45/50
# 51/51 [==============================] - 3s 52ms/step - loss: 0.3463 - accuracy: 0.8715 - val_loss: 0.5484 - val_accuracy: 0.8049
# Epoch 46/50
# 51/51 [==============================] - 3s 53ms/step - loss: 0.3205 - accuracy: 0.8820 - val_loss: 0.5721 - val_accuracy: 0.8111
# Epoch 47/50
# 51/51 [==============================] - 3s 52ms/step - loss: 0.3031 - accuracy: 0.8854 - val_loss: 0.6027 - val_accuracy: 0.8160
# Epoch 48/50
# 51/51 [==============================] - 3s 55ms/step - loss: 0.3056 - accuracy: 0.8826 - val_loss: 0.5848 - val_accuracy: 0.8086
# Epoch 49/50
# 51/51 [==============================] - 3s 54ms/step - loss: 0.3162 - accuracy: 0.8848 - val_loss: 0.6363 - val_accuracy: 0.8160
# Epoch 50/50
# 51/51 [==============================] - 3s 52ms/step - loss: 0.3521 - accuracy: 0.8672 - val_loss: 0.5742 - val_accuracy: 0.8062

# %%
epochs = list(range(len(history.history['accuracy'])))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)

accuracy_score(y_true, y_pred), cm
# Out:
# 26/26 [==============================] - 0s 13ms/step
# (0.8061728395061728,
#  array([[106,   2,   3,   7,   3,   0,   2],
#         [  4,  98,   1,   5,   1,   7,   1],
#         [  4,   4,  81,  12,   3,   7,   4],
#         [  7,   0,   3,  94,   1,   3,   6],
#         [  0,   0,   1,   1,  75,   2,   1],
#         [  1,   3,  10,   4,   8, 102,   3],
#         [  3,   9,   2,   8,   3,   8,  97]], dtype=int64))

# %%
#save model
model.save('Models\emotion_detection_mixed_LSTM_1.keras')
