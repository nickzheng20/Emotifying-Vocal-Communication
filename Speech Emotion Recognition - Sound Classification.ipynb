# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the Dataset

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('TESS data'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break

print(labels[:5])
print('Dataset is Loaded')
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
paths[:5]
# Out:
# ['TESS data\\OAF_angry\\OAF_back_angry.wav',
#  'TESS data\\OAF_angry\\OAF_bar_angry.wav',
#  'TESS data\\OAF_angry\\OAF_base_angry.wav',
#  'TESS data\\OAF_angry\\OAF_bath_angry.wav',
#  'TESS data\\OAF_angry\\OAF_bean_angry.wav']

# %%
labels[:5]
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']

# %%
## Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                    speech  label
# 0  TESS data\OAF_angry\OAF_back_angry.wav  angry
# 1   TESS data\OAF_angry\OAF_bar_angry.wav  angry
# 2  TESS data\OAF_angry\OAF_base_angry.wav  angry
# 3  TESS data\OAF_angry\OAF_bath_angry.wav  angry
# 4  TESS data\OAF_angry\OAF_bean_angry.wav  angry

# %%
df['label'].value_counts()
# Out:
# label
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: count, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(data=df, x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Feature Extraction

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-3.96986206e+02,  7.74405365e+01, -1.95927906e+01, -2.16666889e+01,
#        -2.11275601e+00,  1.00753632e+01, -2.03667068e+01, -6.09244919e+00,
#        -7.21228313e+00, -5.57366073e-01, -1.83255339e+00,  2.02101618e-01,
#         7.27550924e-01,  1.31773746e+00,  2.88633800e+00,  2.85579062e+00,
#        -4.71292210e+00, -4.43651056e+00, -1.62115955e+00, -1.02398405e+01,
#        -7.55126143e+00, -1.79688025e+00, -7.03765249e+00,  9.43658352e+00,
#         8.35585499e+00,  2.17123604e+01,  1.92169914e+01,  2.03489265e+01,
#         1.34133663e+01,  8.33917236e+00,  3.94722193e-01,  5.11131477e+00,
#         9.56873894e+00,  5.45486784e+00,  2.50996375e+00, -1.82390714e+00,
#         4.86896229e+00,  9.31392288e+00,  2.08914971e+00, -1.90649164e+00],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-396.9862, 77.44054, -19.59279, -21.666689, -...
# 1       [-465.73267, 98.77373, 0.65600884, -32.74544, ...
# 2       [-429.79196, 46.124, 1.555048, -0.21709408, 2....
# 3       [-403.46118, 76.3237, -12.531774, -22.288858, ...
# 4       [-434.05756, 77.4455, 10.8654995, 16.092943, 8...
#                               ...
# 2795    [-553.2201, 89.83577, 27.215466, 16.407124, 19...
# 2796    [-589.23676, 96.20407, 36.96118, 15.014446, 28...
# 2797    [-533.41815, 85.43242, 27.791998, 19.307178, 2...
# 2798    [-548.6142, 110.16424, 31.91024, 12.572517, 22...
# 2799    [-549.2962, 102.374565, 32.268833, 26.261616, ...
# Name: speech, Length: 2800, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %% [markdown]
# ## Create the LSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\19746\anaconda3\envs\CS539\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\19746\anaconda3\envs\CS539\Lib\site-packages\keras\src\layers\rnn\lstm.py:148: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\19746\anaconda3\envs\CS539\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               264192
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 305799 (1.17 MB)
# Trainable params: 305799 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\19746\anaconda3\envs\CS539\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\19746\anaconda3\envs\CS539\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 35/35 [==============================] - 5s 87ms/step - loss: 1.1111 - accuracy: 0.5982 - val_loss: 1.0327 - val_accuracy: 0.4107
# Epoch 2/50
# 35/35 [==============================] - 3s 79ms/step - loss: 0.3533 - accuracy: 0.8754 - val_loss: 0.2626 - val_accuracy: 0.9071
# Epoch 3/50
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1852 - accuracy: 0.9455 - val_loss: 0.4092 - val_accuracy: 0.8768
# Epoch 4/50
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1146 - accuracy: 0.9607 - val_loss: 0.1694 - val_accuracy: 0.9286
# Epoch 5/50
# 35/35 [==============================] - 3s 77ms/step - loss: 0.1632 - accuracy: 0.9522 - val_loss: 0.3057 - val_accuracy: 0.8821
# Epoch 6/50
# 35/35 [==============================] - 3s 74ms/step - loss: 0.1004 - accuracy: 0.9661 - val_loss: 0.0656 - val_accuracy: 0.9804
# Epoch 7/50
# 35/35 [==============================] - 2s 64ms/step - loss: 0.0773 - accuracy: 0.9754 - val_loss: 0.1566 - val_accuracy: 0.9375
# Epoch 8/50
# 35/35 [==============================] - 2s 60ms/step - loss: 0.1093 - accuracy: 0.9625 - val_loss: 0.1434 - val_accuracy: 0.9500
# Epoch 9/50
# 35/35 [==============================] - 2s 58ms/step - loss: 0.0719 - accuracy: 0.9777 - val_loss: 0.0837 - val_accuracy: 0.9643
# Epoch 10/50
# 35/35 [==============================] - 2s 61ms/step - loss: 0.0377 - accuracy: 0.9893 - val_loss: 0.0287 - val_accuracy: 0.9911
# Epoch 11/50
# 35/35 [==============================] - 2s 60ms/step - loss: 0.0926 - accuracy: 0.9710 - val_loss: 0.0581 - val_accuracy: 0.9786
# Epoch 12/50
# 35/35 [==============================] - 3s 72ms/step - loss: 0.0325 - accuracy: 0.9884 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 13/50
# 35/35 [==============================] - 2s 69ms/step - loss: 0.0603 - accuracy: 0.9821 - val_loss: 0.1052 - val_accuracy: 0.9679
# Epoch 14/50
# 35/35 [==============================] - 2s 66ms/step - loss: 0.0743 - accuracy: 0.9781 - val_loss: 0.0925 - val_accuracy: 0.9696
# Epoch 15/50
# 35/35 [==============================] - 2s 61ms/step - loss: 0.0342 - accuracy: 0.9893 - val_loss: 0.0155 - val_accuracy: 0.9964
# Epoch 16/50
# 35/35 [==============================] - 2s 63ms/step - loss: 0.0302 - accuracy: 0.9915 - val_loss: 0.1543 - val_accuracy: 0.9500
# Epoch 17/50
# 35/35 [==============================] - 2s 68ms/step - loss: 0.0331 - accuracy: 0.9884 - val_loss: 0.0598 - val_accuracy: 0.9768
# Epoch 18/50
# 35/35 [==============================] - 2s 67ms/step - loss: 0.0395 - accuracy: 0.9897 - val_loss: 0.0359 - val_accuracy: 0.9875
# Epoch 19/50
# 35/35 [==============================] - 2s 64ms/step - loss: 0.0277 - accuracy: 0.9929 - val_loss: 0.0145 - val_accuracy: 0.9929
# Epoch 20/50
# 35/35 [==============================] - 2s 59ms/step - loss: 0.0175 - accuracy: 0.9955 - val_loss: 0.0844 - val_accuracy: 0.9679
# Epoch 21/50
# 35/35 [==============================] - 2s 58ms/step - loss: 0.0257 - accuracy: 0.9911 - val_loss: 0.0172 - val_accuracy: 0.9929
# Epoch 22/50
# 35/35 [==============================] - 2s 61ms/step - loss: 0.0164 - accuracy: 0.9964 - val_loss: 0.0169 - val_accuracy: 0.9946
# Epoch 23/50
# 35/35 [==============================] - 2s 61ms/step - loss: 0.0280 - accuracy: 0.9906 - val_loss: 0.0090 - val_accuracy: 0.9946
# Epoch 24/50
# 35/35 [==============================] - 2s 68ms/step - loss: 0.0160 - accuracy: 0.9929 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 25/50
# 35/35 [==============================] - 3s 72ms/step - loss: 0.0076 - accuracy: 0.9982 - val_loss: 0.0067 - val_accuracy: 0.9964
# Epoch 26/50
# 35/35 [==============================] - 2s 58ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.0215 - val_accuracy: 0.9893
# Epoch 27/50
# 35/35 [==============================] - 2s 60ms/step - loss: 0.0124 - accuracy: 0.9960 - val_loss: 7.8784e-04 - val_accuracy: 1.0000
# Epoch 28/50
# 35/35 [==============================] - 2s 59ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.7428e-04 - val_accuracy: 1.0000
# Epoch 29/50
# 35/35 [==============================] - 2s 59ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 7.2738e-04 - val_accuracy: 1.0000
# Epoch 30/50
# 35/35 [==============================] - 2s 59ms/step - loss: 7.1034e-04 - accuracy: 1.0000 - val_loss: 1.8908e-04 - val_accuracy: 1.0000
# Epoch 31/50
# 35/35 [==============================] - 2s 58ms/step - loss: 4.6782e-04 - accuracy: 1.0000 - val_loss: 9.2035e-05 - val_accuracy: 1.0000
# Epoch 32/50
# 35/35 [==============================] - 2s 62ms/step - loss: 3.4576e-04 - accuracy: 1.0000 - val_loss: 8.1497e-05 - val_accuracy: 1.0000
# Epoch 33/50
# 35/35 [==============================] - 2s 61ms/step - loss: 3.5160e-04 - accuracy: 1.0000 - val_loss: 7.5380e-05 - val_accuracy: 1.0000
# Epoch 34/50
# 35/35 [==============================] - 2s 63ms/step - loss: 5.2804e-04 - accuracy: 1.0000 - val_loss: 9.3346e-05 - val_accuracy: 1.0000
# Epoch 35/50
# 35/35 [==============================] - 2s 60ms/step - loss: 2.1359e-04 - accuracy: 1.0000 - val_loss: 6.0703e-05 - val_accuracy: 1.0000
# Epoch 36/50
# 35/35 [==============================] - 2s 61ms/step - loss: 2.4346e-04 - accuracy: 1.0000 - val_loss: 3.5141e-05 - val_accuracy: 1.0000
# Epoch 37/50
# 35/35 [==============================] - 3s 72ms/step - loss: 1.8980e-04 - accuracy: 1.0000 - val_loss: 2.7990e-05 - val_accuracy: 1.0000
# Epoch 38/50
# 35/35 [==============================] - 3s 73ms/step - loss: 1.8771e-04 - accuracy: 1.0000 - val_loss: 2.8200e-05 - val_accuracy: 1.0000
# Epoch 39/50
# 35/35 [==============================] - 3s 78ms/step - loss: 2.1640e-04 - accuracy: 1.0000 - val_loss: 2.0843e-05 - val_accuracy: 1.0000
# Epoch 40/50
# 35/35 [==============================] - 3s 77ms/step - loss: 1.1519e-04 - accuracy: 1.0000 - val_loss: 2.1336e-05 - val_accuracy: 1.0000
# Epoch 41/50
# 35/35 [==============================] - 3s 73ms/step - loss: 2.7140e-04 - accuracy: 1.0000 - val_loss: 1.8673e-05 - val_accuracy: 1.0000
# Epoch 42/50
# 35/35 [==============================] - 3s 72ms/step - loss: 1.4993e-04 - accuracy: 1.0000 - val_loss: 2.1213e-05 - val_accuracy: 1.0000
# Epoch 43/50
# 35/35 [==============================] - 3s 72ms/step - loss: 1.5756e-04 - accuracy: 1.0000 - val_loss: 1.3767e-05 - val_accuracy: 1.0000
# Epoch 44/50
# 35/35 [==============================] - 3s 72ms/step - loss: 9.1403e-05 - accuracy: 1.0000 - val_loss: 1.6328e-05 - val_accuracy: 1.0000
# Epoch 45/50
# 35/35 [==============================] - 3s 72ms/step - loss: 1.0534e-04 - accuracy: 1.0000 - val_loss: 1.2680e-05 - val_accuracy: 1.0000
# Epoch 46/50
# 35/35 [==============================] - 3s 73ms/step - loss: 1.1006e-04 - accuracy: 1.0000 - val_loss: 9.8492e-06 - val_accuracy: 1.0000
# Epoch 47/50
# 35/35 [==============================] - 3s 73ms/step - loss: 1.3413e-04 - accuracy: 1.0000 - val_loss: 8.7420e-06 - val_accuracy: 1.0000
# Epoch 48/50
# 35/35 [==============================] - 3s 72ms/step - loss: 3.3270e-04 - accuracy: 1.0000 - val_loss: 3.2269e-05 - val_accuracy: 1.0000
# Epoch 49/50
# 35/35 [==============================] - 3s 72ms/step - loss: 0.0063 - accuracy: 0.9991 - val_loss: 0.0333 - val_accuracy: 0.9875
# Epoch 50/50
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1184 - accuracy: 0.9656 - val_loss: 0.3047 - val_accuracy: 0.8839

# %%
# best val accuracy: 72.32
# use checkpoint to save the best val accuracy model
# adjust learning rate for slow convergence

# %% [markdown]
# ## Plot the results

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
